# %% [markdown]
# # Explanation of topic

# %% [markdown]
# ## Movie Recomendation

# %% [markdown]
# For this midterm, I took the basis of the movie recomendation system given as an example, but decided to add a simple chatbot pipeline so that you can request information about movies that are similar to the one initially passed in.

# %%
#Imports
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.datasets import make_classification

# %%
#Reading in data
df = pd.read_csv('metadata_clean.csv')

orig_df = pd.read_csv('movies_metadata.csv', low_memory=False)

# %%
#Cleaning data
df['overview'], df['id'] = orig_df['overview'], orig_df['id']

# %%
#Creating Vectorizer instance with English stopwords
tfidf = TfidfVectorizer(stop_words='english')

# %%
#Filling NA
df['overview'] = df['overview'].fillna('')

# %%
#Preview of data structure
df.iloc[34682]
# Out:
# title                 How the Lion Cub and the Turtle Sang a Song
# genres                                              ['Animation']
# runtime                                                       9.0
# vote_average                                                  6.5
# vote_count                                                    4.0
# year                                                         1974
# overview        The Tortoise composed a song and the Lion cub ...
# id                                                         273126
# Name: 34682, dtype: object

# %%
#Setting up the matrix so we can compare cosine_similarities
tfidf_matrix = tfidf.fit_transform(df['overview'])
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Creating our table of indices for faster lookups
indices = pd.Series(df.index, index=df['title']).drop_duplicates()
indices.head
# Out:
# <bound method NDFrame.head of title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Subdue                         45461
# Century of Birthing            45462
# Betrayal                       45463
# Satan Triumphant               45464
# Queerama                       45465
# Length: 45466, dtype: int64>

# %%
def content_recommender(title):
    idx = indices[title]
    #Listing cosine similarities
    sim_scores = list(enumerate(cosine_sim[idx]))
    #Reordering so highest score is first
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse =True)
    #creating a list of top 20
    sim_scores = sim_scores[1:21]
    #Fetching the data for found indices
    movie_indices = [i[0] for i in sim_scores]
    #Returning data
    return df.iloc[movie_indices]

# %%
content_recommender('How the Lion Cub and the Turtle Sang a Song')
# Out:
#                                        title  \
# 359                            The Lion King
# 36290                                    Bad
# 42829                                   Prey
# 19252              The Tortoise and the Hare
# 17041                           African Cats
# 33842                          Gangster High
# 33778                                 Broken
# 33798                                Howling
# 14177                                 Thirst
# 27933      Massaï, les guerriers de la pluie
# 19947                     The Day He Arrives
# 25654                         Fearless Fagan
# 6094                               Born Free
# 31111                        The Art of Love
# 20179                             Fish Story
# 3293                                The Bear
# 8637                      Alice's Restaurant
# 8692   Lone Wolf and Cub: Sword of Vengeance
# 33825                  Running Out of Time 2
# 25617                         Face The Music
#
#                                        genres  runtime  vote_average  \
# 359          ['Family', 'Animation', 'Drama']     89.0           8.0
# 36290                               ['Music']     17.0           7.6
# 42829                  ['Horror', 'Thriller']      0.0           5.9
# 19252                           ['Animation']      9.0           6.8
# 17041  ['Documentary', 'Family', 'Adventure']     89.0           7.1
# 33842                     ['Action', 'Crime']    100.0           6.2
# 33778        ['Thriller', 'Drama', 'Mystery']    122.0           6.6
# 33798      ['Thriller', 'Mystery', 'Foreign']    114.0           5.9
# 14177         ['Drama', 'Horror', 'Thriller']    133.0           7.0
# 27933                  ['Adventure', 'Drama']     94.0           8.5
# 19947                    ['Drama', 'Foreign']     79.0           6.9
# 25654                              ['Comedy']     79.0          10.0
# 6094         ['Family', 'Adventure', 'Drama']     95.0           6.5
# 31111                   ['Romance', 'Comedy']     85.0           5.4
# 20179            ['Music', 'Drama', 'Comedy']    112.0           7.0
# 3293         ['Adventure', 'Drama', 'Family']     94.0           6.9
# 8637             ['Drama', 'Comedy', 'Music']    111.0           5.5
# 8692                      ['Drama', 'Action']     83.0           7.1
# 33825         ['Thriller', 'Action', 'Crime']     95.0           5.8
# 25617                                      []     90.0           5.2
#
#        vote_count  year                                           overview  \
# 359        5520.0  1994  A young lion cub named Simba can't wait to be ...
# 36290        20.0  1987  "Bad" is a song by American song writer and re...
# 42829         8.0  2016           A Lion Terrorizes the City of Amsterdam.
# 19252        21.0  1935  The Tortoise and the Hare is an animated short...
# 17041        74.0  2011  African Cats captures the real-life love, humo...
# 33842        13.0  2006  Sang-ho is an ordinary high school student. Hi...
# 33778        15.0  2014  Sang-Hyun, who lost his wife, lives with his d...
# 33798        33.0  2012  A man is found burned to death inside of a car...
# 14177       198.0  2009  Sang-hyun (Song Kang-ho), a respected priest, ...
# 27933         2.0  2004  After a lion kills the village leader, the exp...
# 19947        27.0  2011  Sang-Joon is a professor in the film departmen...
# 25654         1.0  1952  A young man brings his pet lion with him when ...
# 6094         38.0  1966  Born Free (1966) is an Open Road Films Ltd./Co...
# 31111        17.0  2011  The Art of Love is composed of several chapter...
# 20179        19.0  2009  A rock band writes a song called "Fish Story" ...
# 3293         85.0  1988  An orphan bear cub hooks up with an adult male...
# 8637         22.0  1969  Alice's Restaurant is a 1969 movie adapted fro...
# 8692         36.0  1972  In this first film of the Lone Wolf and Cub se...
# 33825        13.0  2001  Ho Sheung Sang finds himself wrapped up in ano...
# 25617         3.0  1993  Divorced couple Charlie and Lisa Hunter once a...
#
#            id
# 359      8587
# 36290  342381
# 42829  400610
# 19252   58159
# 17041   57586
# 33842   40122
# 33778  264273
# 33798  116227
# 14177   22536
# 27933   74684
# 19947   85525
# 25654  241804
# 6094    15347
# 31111   92424
# 20179   38010
# 3293     2383
# 8637     5638
# 8692    41471
# 33825   45303
# 25617  131903

# %%
#Creation of chatbot pipeline to be used in recommendation bot.
text_clf = Pipeline([
    ('BOW', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', MultinomialNB())
])

# %%
def recommendation_bot(title):
    i = 0
    ids = []
    #Calls content recommender created previously
    movies = content_recommender(title)
    print(movies['title'])
    #Fits previously created pipeline and fits it to the indices found from recommendations
    text_clf.fit(movies['title'], movies.index)
    #Request input from user
    movie = input('If you would like to see some overviews, please enter the names of any of the following movies. No need to make sure it is exact. \nType "done" if not.\n')
    while (movie != 'done'):
        movie = [movie]
        #Predicts movie title based off of input
        id = int(text_clf.predict(movie))
        ids.append(id)
        #Request input from user
        movie = input('Any more movies to add to the overview? \nType "done" if not.\n')
    #Prints information for movies selected
    return df.iloc[ids]

# %%
recommendation_bot('The Lion King')
# Out:
# 34682    How the Lion Cub and the Turtle Sang a Song
# 9353                                The Lion King 1½
# 9115                  The Lion King 2: Simba's Pride
# 42829                                           Prey
# 25654                                 Fearless Fagan
# 17041                                   African Cats
# 27933              Massaï, les guerriers de la pluie
# 6094                                       Born Free
# 37409                                     Sour Grape
# 3203                                The Waiting Game
# 14402           Michael Jackson: Life of a Superstar
# 3293                                        The Bear
# 31208                                     White Lion
# 34754                             Helen the Baby Fox
# 37278                          The Little Bear Movie
# 35242                              His Name was King
# 31439                   Michael Jackson: Number Ones
# 34095                          Knives of the Avenger
# 6574                   Once Upon a Time in China III
# 18630                                   October Baby
# Name: title, dtype: object
# If you would like to see some overviews, please enter the names of any of the following movies. No need to make sure it is exact.
# Type "done" if not.
# prey
# Any more movies to add to the overview?
# Type "done" if not.
# little bear movie
# Any more movies to add to the overview?
# Type "done" if not.
# knives of avenger
# Any more movies to add to the overview?
# Type "done" if not.
# done
#                        title                   genres  runtime  vote_average  \
# 42829                   Prey   ['Horror', 'Thriller']      0.0           5.9
# 37278  The Little Bear Movie  ['Animation', 'Family']     75.0           6.0
# 34095  Knives of the Avenger  ['Action', 'Adventure']     85.0           5.5
#
#        vote_count  year                                           overview  \
# 42829         8.0  2016           A Lion Terrorizes the City of Amsterdam.
# 37278         2.0  2001  Little Bear and Father Bear go camping in the ...
# 34095         3.0  1966  A mysterious knife-throwing viking warrior pro...
#
#            id
# 42829  400610
# 37278   33371
# 34095   66087

# %% [markdown]
# # Conclusion

# %% [markdown]
# I tried to use the pipline to be used to look up the movie before the recommendations so that perfect spelling and capitalization is not required and allows you to find movies that you are unsure of the exact title for. That did function, but frankly it was extremely slow. I think I need to learn more about how to make efficient search engines before attempting to parse through over 45000 records to compare titles. I ended up settling for a small pipeline that allows the user to request data on one of the movie recomendations without having to have proper capitalization or perfect setting. 20 records is small enough that the pipeline can be fit to a new dataset every time, which allows it to be used as part of a runtime-function. For future additions, I would love to add the ability to search for movies in the entire dataset through pipeline, but a more efficient search is needed. Expanding on the chatbot would also be ideal, that way the user can ask for specific information instead of the entire overview.
